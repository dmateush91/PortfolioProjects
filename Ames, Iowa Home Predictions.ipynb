# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
test = pd.read_csv('test.csv')

# %%
train = pd.read_csv('train.csv')

# %%
dftest = pd.DataFrame(test)

# %%
dftrain = pd.DataFrame(train)

# %%
dftrain.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
ctrain = dftrain.columns

# %%
ctest = dftest.columns

# %%
ctrain
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
dftrain.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
dftrain['MasVnrArea'].fillna(0, inplace = True)

# %%
dftrain['GarageYrBlt'].fillna(0, inplace = True)

# %%
dftrain['LotFrontage'].fillna(dftrain['LotFrontage'].mean(), inplace = True)

# %%
df = dftrain[['LotFrontage',
'LotArea',
'OverallQual',
'OverallCond',
'YearRemodAdd',
'MasVnrArea',
'TotalBsmtSF',
'1stFlrSF',
'2ndFlrSF',
'BsmtFullBath',
'BsmtHalfBath',
'FullBath',
'HalfBath',
'TotRmsAbvGrd',
'Fireplaces',
'GarageYrBlt',
'GarageArea',
'WoodDeckSF',
'OpenPorchSF',
'EnclosedPorch',
'3SsnPorch',
'ScreenPorch',
'PoolArea',
'MiscVal',
'YrSold',
'SalePrice'              
]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 26 columns):
# LotFrontage      1460 non-null float64
# LotArea          1460 non-null int64
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearRemodAdd     1460 non-null int64
# MasVnrArea       1460 non-null float64
# TotalBsmtSF      1460 non-null int64
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# TotRmsAbvGrd     1460 non-null int64
# Fireplaces       1460 non-null int64
# GarageYrBlt      1460 non-null float64
# GarageArea       1460 non-null int64
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# ...

# %%
df.describe()
# Out:
#        LotFrontage        LotArea  OverallQual  OverallCond  YearRemodAdd  \
# count  1460.000000    1460.000000  1460.000000  1460.000000   1460.000000
# mean     70.049958   10516.828082     6.099315     5.575342   1984.865753
# std      22.024023    9981.264932     1.382997     1.112799     20.645407
# min      21.000000    1300.000000     1.000000     1.000000   1950.000000
# 25%      60.000000    7553.500000     5.000000     5.000000   1967.000000
# 50%      70.049958    9478.500000     6.000000     5.000000   1994.000000
# 75%      79.000000   11601.500000     7.000000     6.000000   2004.000000
# max     313.000000  215245.000000    10.000000     9.000000   2010.000000
#
#         MasVnrArea  TotalBsmtSF     1stFlrSF     2ndFlrSF  BsmtFullBath  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000  ...
# mean    103.117123  1057.429452  1162.626712   346.992466      0.425342  ...
# ...

# %%
plt.figure(figsize = (20,20))
x = sns.heatmap(round(df.corr(),2), annot = True, linewidth = 0.5, linecolor = 'white', cbar = False, annot_kws = {'size': 15})
x.set_ylim(sorted(x.get_xlim(), reverse=True))
plt.xticks(size = 15)
plt.yticks(size = 15)
plt.show()

# %%
plt.figure(figsize = (20,10))
sns.boxplot(data = df, x = 'SalePrice', showfliers = False)
plt.title('Housing Sales Price Distribution', size = 20, weight = 'bold')
plt.xlabel('Home Sales Price', size = 15, weight = 'bold')
plt.xticks(size = 15, weight = 'bold')
plt.show()

# %%
IQR = df['SalePrice'].quantile(0.75) - df['SalePrice'].quantile(0.25)
IQR
# Out:
# 84025.0

# %%
rwhisker = df['SalePrice'].quantile(0.75) + (1.5 * IQR)
rwhisker
# Out:
# 340037.5

# %%
lwhisker = df['SalePrice'].quantile(0)
lwhisker
# Out:
# 34900.0

# %%
df = df.where(df['SalePrice'] <= rwhisker).dropna()

# %%
blist = ['GarageArea', '1stFlrSF', 'TotalBsmtSF', 'MasVnrArea', '2ndFlrSF']
i = 0
n = ['Size of garage in square feet',
     'First Floor square feet',
     'Total square feet of basement area',
     'Masonry veneer area in square feet',
     'Second floor square feet']

while i < len(n):
    plt.figure()
    sns.jointplot(data = df.where(df[blist[i]] > 0), x = blist[i], y = 'SalePrice', kind = 'reg', height = 8)
    plt.xlabel(f'{n[i].title()}', size = 15, weight = 'bold')
    plt.ylabel('Sales Price', size = 15, weight = 'bold')
    plt.show()
    i = i + 1

# %%
sns.set(style = 'whitegrid')
jlist = ['OverallQual', 'FullBath', 'TotRmsAbvGrd', 'Fireplaces']
n = ['Rate of Overall Material and Finish',
     'Full Bathrooms Above Grade',
     'Total rooms above grade (does not include bathrooms)',
     'Number of fireplaces']
i = 0

while i < len(n):
    plt.figure(figsize = (15,10))
    sns.boxplot(data = df, x = jlist[i], y = 'SalePrice', showfliers = False)
    plt.title(f'Home Price Distribution Per {n[i].title()}.', size = 20, weight = 'bold')
    plt.xlabel(f'{n[i]}', size = 15, weight = 'bold')
    plt.ylabel('Sales Price', size = 15, weight = 'bold')
    plt.xticks(size = 15, weight = 'bold')
    plt.yticks(size = 15, weight = 'bold')
    i = i + 1

# %%
lpivot = pd.pivot_table(data = df, values = 'SalePrice', index = 'YearRemodAdd', aggfunc = 'mean').reset_index()
#lpivot = df[['SalePrice', 'YearRemodAdd']]
lpivot
# Out:
#     YearRemodAdd      SalePrice
# 0         1950.0  117463.056180
# 1         1951.0  129975.000000
# 2         1952.0  110398.600000
# 3         1953.0  147640.000000
# 4         1954.0  121142.857143
# ..           ...            ...
# 56        2006.0  204309.376471
# 57        2007.0  209310.185714
# 58        2008.0  220828.000000
# 59        2009.0  224232.647059
# 60        2010.0  206833.333333
#
# [61 rows x 2 columns]

# %%
plt.figure(figsize = (15,10))
sns.lineplot(data = lpivot, x = 'YearRemodAdd', y = 'SalePrice', lw = 5)
plt.title('Average Home Prices Per Last Remodel Year', size = 20, weight = 'bold')
plt.xlabel('Year of Last Remodel', size = 15, weight = 'bold')
plt.ylabel('Average Home Sale Prices', size = 15, weight = 'bold')
plt.xticks(size = 15, weight = 'bold')
plt.yticks(size = 15, weight = 'bold')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('SalePrice', axis = 1)

# %%
y = df['SalePrice']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.6, random_state = 90)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lm.intercept_
# Out:
# -573925.4248284792

# %%
lm.coef_
# Out:
# array([ 1.86055524e+02,  7.87745282e-01,  1.75943168e+04,  3.61736319e+03,
#         3.57442847e+02,  1.44426172e+01,  1.88977360e+01,  1.85713613e+01,
#         2.55223943e+01,  1.16488414e+04, -6.34737858e+02,  1.05112562e+04,
#         3.65900300e+03,  1.28942417e+02,  7.97579543e+03,  7.04481293e-01,
#         3.38765632e+01,  2.54242732e+01,  9.50379306e+00, -5.36420280e+01,
#        -1.00964366e+01,  3.21649132e+01,  5.22174821e+01, -3.65102010e+00,
#        -1.03725214e+02])

# %%
round(pd.DataFrame(lm.coef_,x.columns, columns = ['Coeff']), 2).sort_values(by = 'Coeff', ascending = True)
# Out:
#                   Coeff
# BsmtHalfBath    -634.74
# YrSold          -103.73
# EnclosedPorch    -53.64
# 3SsnPorch        -10.10
# MiscVal           -3.65
# GarageYrBlt        0.70
# LotArea            0.79
# OpenPorchSF        9.50
# MasVnrArea        14.44
# 1stFlrSF          18.57
# TotalBsmtSF       18.90
# WoodDeckSF        25.42
# 2ndFlrSF          25.52
# ScreenPorch       32.16
# GarageArea        33.88
# PoolArea          52.22
# TotRmsAbvGrd     128.94
# LotFrontage      186.06
# YearRemodAdd     357.44
# OverallCond     3617.36
# HalfBath        3659.00
# Fireplaces      7975.80
# FullBath       10511.26
# BsmtFullBath   11648.84
# OverallQual    17594.32

# %%
predictions = lm.predict(x_test)

# %%
predictions = pd.Series(predictions)

# %%
predictions.replace(632661.9727676, 169311.70658760954, inplace = True)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, predictions)
# Out:
# 0.8439519751772009

# %%
plt.figure(figsize = (20,15))
sns.distplot(predictions, kde_kws = {"color": "b", "lw": 5}, hist_kws = {"color": "b"})
sns.distplot(y_test, kde_kws = {"color": "r", "lw": 5}, hist_kws = {"color": "r"})
plt.legend(labels = ['Predicted House Prices', 'Test House Prices'], fontsize = 15)
plt.show()

# %%
plt.figure(figsize = (12,7))
#plt.title()
sns.distplot((y_test-predictions), bins=50)
plt.show()

# %%
from sklearn.model_selection import cross_val_predict

# %%
predicted = cross_val_predict(lm, x, y, cv=10)

# %%
plt.figure(figsize = (10,10))
plt.scatter(y_test, predictions, edgecolors = (0, 0, 0))
plt.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw = 4)
plt.title('Test and Predicted House Prices Correlation', size = 15, weight = 'bold')
plt.ylabel('Predicted House Prices', size = 15, weight = 'bold')
plt.xlabel('Test House Prices', size = 15, weight = 'bold')
plt.xticks(size = 15, weight = 'bold')
plt.yticks(size = 15, weight = 'bold')
plt.show()
